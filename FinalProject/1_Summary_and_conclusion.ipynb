# %% [markdown]
# # Final Project
#
# - > Student Name: Fanjie Kong, Mengxuan Cui, Xinghong Tang

# %% [markdown]
# ## Predicting 1-year Mortality - Long Term Mortality from MIMIC-III dataset

# %% [markdown]
# ### Background

# %% [markdown]
# 1-year Mortality Prediction is one of the primary outcomes of interest of an hospital admission. It helps to track patients’ wellbeing in a long term and also benefits patienet’s high quality, cost-effective medical care. For example, if a patient is predicted dying within 1 year, more specialized course of action should be involved to avoid mortality. Currently, there are a variety of predeiction models associated with motarlity prediction. Our project goal is to build a 1-year Mortality Prediction model based on MIMIC-III Database.
#
#
# ### Task:
# Using the data from the MIMIC-III dataset, create a machine learning model that predicts whether a patient will die within a year of their admission.

# %% [markdown]
# ### Data

# %% [markdown]
# MIMIC-III database is used in this project, accessible via: https://mimic.physionet.org/
#
#
# MIMIC is a relational database containing tables of data relating to patients who stayed within the intensive care units at Beth Israel Deaconess Medical Center. A table is a data storage structure which is similar to a spreadsheet: each column contains consistent information (e.g., patient identifiers), and each row contains an instantiation of that information (e.g. a row could contain the integer 340 in the patient identifier column which would imply that the row’s patient identifier is 340).
# Reference: MIMIC-III dataset overview. https://mimic.physionet.org/gettingstarted/overview/

# %% [markdown]
# ### python libraries requirements:
#     numpy
#     pandas
#     os
#     xgboost
#     scikit-learn
#     scipy
#     matplotlib
#     seaborn
#     keras
#     tensorflow-gpu

# %% [markdown]
# ## Main Results

# %% [markdown]
# ### Scatter matrix plot

# %% [markdown]
# We show the zoom-in scatter matrix of our features. From the scatter matrix plots, we can see that most features are independently distributed. Although we see there are a few features that have strong correlation to the others, these correlations are not absolutely existed. It is not a warranty to eliminate these features

# %%
sc1 = Image(filename='normalized_scatter_plot_2.png') 
sc2 = Image(filename='normalized_scatter_plot_3.png')
display(sc1, sc2)

# %% [markdown]
# ### Model Performance

# %% [markdown]
# In this project, we evaluate the model using accuracy, precision, recall, f1-score and AUC as our metrics. We show that ANN model outperforms the other models.

# %%
from IPython.display import Image
Image(filename='Performance_table.png')

# %%
from IPython.display import Image
Image(filename='ROC_curve.png')

# %% [markdown]
# ### Feature importance
#
#
# The importance of features was measured by XGBoost.

# %%
from IPython.display import Image
Image(filename='Feature_importance.png')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - > Prediction:
# Artificial Neural Network Model performs best among these machine learning models
#
# - >Interpretability:
# we find the top 15 most important features from XGBoost using F-score
#
# - > Limitation and Improvement
#     - > we do not use statistical methods to get p-values of different variables for statistical significance analysis
#     - > we do not have information related to cause of death
#     - > we do not investigate the relation between mortality and notes based on NLP models
