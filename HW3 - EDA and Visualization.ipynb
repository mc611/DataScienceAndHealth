# %% [markdown]
# # HW3 - Exploratory Data Analysis, Visualization, Hypothesis Testing

# %% [markdown]
# In this homework, we are going to pick up exactly where we left off last time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# In this assignment, we will be using the same diabetes dataset as before. Just like last time, create a data folder and place the data inside. Add a `.gitignore` file just like last time to prevent yourself from committing the file:

# %%
diabetes_df = pd.read_csv('./data/diabetic_data.csv')

# %% [markdown]
# # Finding outliers

# %% [markdown]
# During exploratory data analysis, it is generally important to find out if there are any outliers in the data. Outliers can greatly affect certain estimates such as means and standard deviations. In addition, certain types of statistical models do not work well in the presence of outliers.
#
# The statistical way of defining an outlier is generally to see whether it falls outside of the following range:
#
# $$(Q_1 - 1.5 * IQR, Q_3 + 1.5 * IQR)$$,
#
# where $Q_1$ is the 25th percentile, $Q_3$ is the 75th percentile, and the $IQR$ is the difference between them.

# %% [markdown]
# The columns that you will be working with for the following exercise are as follows:
#
#  * `num_lab_procedures`
#  * `num_procedures`
#  * `num_medications`
#  * `number_outpatient`
#  * `number_emergency`
#  * `number_inpatient`
#  * `number_diagnoses`

# %% [markdown]
# ## For each of the above columns, plot a histogram of the values [5 pts]
#
# You can use any method that you would like

# %%
diabetes_df.hist('num_lab_procedures')
diabetes_df.hist('num_procedures')
diabetes_df.hist('num_medications')
diabetes_df.hist('number_outpatient')
diabetes_df.hist('number_emergency')
diabetes_df.hist('number_inpatient')
diabetes_df.hist('number_diagnoses')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ccf1860>]],
#       dtype=object)

# %% [markdown]
# ## Find the encounter ids which are outliers in each of the columns listed above [15 pts]
#
# > In order to do this, first compute the bounds for outliers as noted above for each of the columns necessary. Then, find the `encounter_id`s which have outlier values for each column and display them.

# %%
q1 = np.percentile(diabetes_df['num_lab_procedures'], 25)
q3 = np.percentile(diabetes_df['num_lab_procedures'], 75)
iqr = q3-q1
outliers1 = q1-1.5*iqr
outliers2 = q3+1.5*iqr
df1 = diabetes_df[(diabetes_df['num_lab_procedures']<outliers1)|(diabetes_df['num_lab_procedures']>outliers2)]
df1[['encounter_id','num_lab_procedures']]
# Out:
#         encounter_id  num_lab_procedures
# 336          3331848                 103
# 623          4936380                  97
# 823          6479016                 105
# 830          6494982                 103
# 1079         7978098                  98
# 1545        10503348                 102
# 1595        10754916                 100
# 2619        16956072                 105
# 2673        17227758                  97
# 2857        18283560                  97
# 2928        18743664                 101
# 3099        19673208                  98
# 3968        23417688                 102
# 5485        28454754                  99
# 6298        31398072                 100
# 6522        32176266                 114
# 6694        32760876                 101
# 6781        33120834                  97
# 7728        36074274                  97
# 7737        36089712                 113
# 8938        39644706                 103
# 9470        41263296                  98
# 10556       44614098                 105
# 10671       44964066                 102
# 11478       47484624                  98
# 11945       49014930                 111
# 12653       51226458                  97
# 13163       52701030                 129
# 13885       54665280                  97
# 15532       59536380                 107
# ...              ...                 ...
# 79682      244835376                  97
# 84839      268003482                  98
# 85204      269689188                 106
# 85867      272400348                 109
# 86297      274455804                 121
# 88100      282524652                  99
# 88208      282942948                 108
# 88650      285351102                 108
# 89795      290795556                  97
# 90624      297903518                  97
# 90838      301361900                  97
# 91410      309003956                 126
# 91639      311932982                 103
# 91776      313754882                  97
# 92379      321347684                 101
# 92751      326641136                 100
# 93176      332007476                  97
# 94139      344811806                  97
# 94464      348481808                 101
# 94558      349640264                 101
# 95025      356032760                 118
# 95516      362671838                  98
# 96081      370766150                 100
# 96266      373122344                  97
# 99591      414997262                  99
# 100457     426109136                 100
# 100671     429083114                  97
# 101541     440811602                  98
# 101587     441462884                 101
# 101671     442606028                  98
#
# [143 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['num_procedures'], 25)
q3 = np.percentile(diabetes_df['num_procedures'], 75)
iqr = q3-q1
outliers3 = q1-1.5*iqr
outliers4 = q3+1.5*iqr
df2 = diabetes_df[(diabetes_df['num_procedures']<outliers3)|(diabetes_df['num_procedures']>outliers4)]
df2[['encounter_id','num_procedures']]
# Out:
#         encounter_id  num_procedures
# 5              35754               6
# 120          2087892               6
# 147          2363592               6
# 155          2466036               6
# 221          2789766               6
# 225          2798190               6
# 237          2843922               6
# 279          3043686               6
# 281          3044688               6
# 285          3051324               6
# 297          3118128               6
# 325          3291906               6
# 362          3482724               6
# 363          3483090               6
# 375          3590394               6
# 385          3629472               6
# 386          3634938               6
# 411          3782454               6
# 428          3894402               6
# 445          3982836               6
# 458          4080900               6
# 459          4084140               6
# 464          4089042               6
# 466          4099092               6
# 489          4218042               6
# 499          4253874               6
# 505          4262964               6
# 544          4488132               6
# 564          4582062               6
# 575          4664574               6
# ...              ...             ...
# 101387     438536900               6
# 101395     438559034               6
# 101420     439040276               6
# 101438     439122542               6
# 101443     439141790               6
# 101444     439148210               6
# 101454     439602032               6
# 101462     439630898               6
# 101465     439638182               6
# 101469     439687376               6
# 101479     439723898               6
# 101535     440774228               6
# 101541     440811602               6
# 101575     441383192               6
# 101583     441450614               6
# 101587     441462884               6
# 101611     441950420               6
# 101617     441968210               6
# 101638     442050440               6
# 101676     442629116               6
# 101686     443110592               6
# 101715     443226344               6
# 101717     443237984               6
# 101719     443256548               6
# 101725     443699066               6
# 101739     443775740               6
# 101747     443804570               6
# 101751     443835140               6
# 101755     443842022               6
# 101756     443842070               6
#
# [4954 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['num_medications'], 25)
q3 = np.percentile(diabetes_df['num_medications'], 75)
iqr = q3-q1
outliers5 = q1-1.5*iqr
outliers6 = q3+1.5*iqr
df3 = diabetes_df[(diabetes_df['num_medications']<outliers5)|(diabetes_df['num_medications']>outliers6)]
df3[['encounter_id','num_medications']]
# Out:
#         encounter_id  num_medications
# 149          2373468               39
# 336          3331848               61
# 361          3479946               40
# 411          3782454               46
# 466          4099092               41
# 511          4329624               36
# 657          5184162               41
# 728          5593794               50
# 757          5836536               43
# 783          6094530               46
# 816          6402138               42
# 820          6463974               37
# 854          6722676               51
# 1079         7978098               42
# 1082         7980534               38
# 1128         8228502               45
# 1166         8381406               43
# 1191         8439372               36
# 1298         9089646               40
# 1299         9118542               37
# 1415         9785502               36
# 1483        10086672               42
# 1515        10320138               45
# 1576        10671636               38
# 1684        11195616               36
# 1692        11217222               54
# 1765        11653992               40
# 1790        11723160               36
# 1823        11945154               37
# 1875        12142584               42
# ...              ...              ...
# 100272     423733844               50
# 100323     424362710               39
# 100396     425459786               38
# 100474     426159566               44
# 100515     426745298               43
# 100606     428405960               41
# 100647     429014294               37
# 100689     429593120               47
# 100772     430780628               38
# 100786     430820624               39
# 100815     431358680               43
# 100863     431979830               57
# 100874     431998226               36
# 100884     432035432               36
# 100945     432673982               50
# 100950     433101896               46
# 101011     433743440               57
# 101061     434379458               47
# 101314     437868344               46
# 101324     437901938               39
# 101353     438429074               50
# 101439     439129376               37
# 101443     439141790               40
# 101540     440808020               36
# 101541     440811602               42
# 101572     441364850               40
# 101587     441462884               38
# 101619     441971366               36
# 101715     443226344               64
# 101751     443835140               65
#
# [2557 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['number_outpatient'], 25)
q3 = np.percentile(diabetes_df['number_outpatient'], 75)
iqr = q3-q1
outliers7 = q1-1.5*iqr
outliers8 = q3+1.5*iqr
df4 = diabetes_df[(diabetes_df['number_outpatient']<outliers7)|(diabetes_df['number_outpatient']>outliers8)]
df4[['encounter_id','number_outpatient']]
# Out:
#         encounter_id  number_outpatient
# 2              64410                  2
# 53            591996                  1
# 78           1069716                  1
# 82           1079592                  1
# 128          2140146                  1
# 130          2226870                  1
# 167          2530254                  5
# 246          2874540                  2
# 304          3156462                  7
# 538          4477266                  1
# 585          4734798                  1
# 733          5654628                  9
# 735          5657328                  1
# 744          5693046                  3
# 756          5835240                  1
# 843          6608874                  1
# 883          6896670                  1
# 940          7212504                  9
# 958          7292178                  3
# 991          7432920                  1
# 1114         8065074                  1
# 1213         8607732                  1
# 1300         9142626                  2
# 1304         9155802                  1
# 1305         9160878                  3
# 1318         9225600                  1
# 1519        10325892                  1
# 1550        10563816                  1
# 1582        10737954                  8
# 1586        10741938                  5
# ...              ...                ...
# 101594     441481382                  1
# 101605     441924596                  2
# 101614     441956810                  1
# 101617     441968210                  1
# 101625     441986012                  3
# 101626     441986030                  1
# 101636     442039472                  2
# 101640     442077494                  2
# 101643     442090892                  1
# 101648     442105448                  3
# 101650     442515896                 11
# 101655     442533620                  1
# 101656     442541672                  1
# 101658     442552658                  5
# 101666     442576412                  1
# 101670     442591346                  1
# 101673     442606676                  5
# 101677     442635584                  1
# 101702     443186306                  2
# 101705     443192912                  2
# 101714     443222108                  3
# 101721     443282564                  9
# 101736     443739152                  1
# 101739     443775740                  2
# 101743     443793668                  1
# 101746     443797298                  1
# 101756     443842070                  1
# 101759     443842778                  3
# 101760     443847176                  3
# 101763     443854148                  1
#
# [16739 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['number_emergency'], 25)
q3 = np.percentile(diabetes_df['number_emergency'], 75)
iqr = q3-q1
outliers9 = q1-1.5*iqr
outliers10 = q3+1.5*iqr
df5 = diabetes_df[(diabetes_df['number_emergency']<outliers9)|(diabetes_df['number_emergency']>outliers10)]
df5[['encounter_id','number_emergency']]
# Out:
#         encounter_id  number_emergency
# 12             40926                 1
# 60            676422                 1
# 167          2530254                 1
# 175          2552952                 1
# 199          2652750                 1
# 246          2874540                 1
# 569          4654188                 1
# 673          5264082                 1
# 703          5357160                 1
# 734          5655186                 1
# 755          5828766                 1
# 776          6065928                 1
# 840          6582546                 1
# 883          6896670                 2
# 991          7432920                 1
# 1056         7908588                 1
# 1325         9251970                 1
# 1338         9338766                 1
# 1390         9618930                 1
# 1465         9939354                 1
# 1499        10213620                 1
# 1680        11191398                 1
# 1716        11326656                 4
# 1851        12090540                 2
# 2008        13026294                 1
# 2212        14462742                 1
# 2320        15183996                 2
# 2335        15358140                 1
# 2380        15642504                 1
# 2428        15890826                 1
# ...              ...               ...
# 101545     440813090                 2
# 101555     440852402                 5
# 101561     440879594                 1
# 101562     440882450                 1
# 101567     440926064                 3
# 101579     441412274                 5
# 101591     441473204                 2
# 101596     441488810                 1
# 101599     441502826                 2
# 101621     441979310                16
# 101629     442000934                 7
# 101631     442012304                 1
# 101650     442515896                 2
# 101654     442533584                 1
# 101655     442533620                 2
# 101658     442552658                 5
# 101661     442558928                 1
# 101674     442621412                 2
# 101680     442647692                 2
# 101681     442650974                 1
# 101696     443149208                 1
# 101702     443186306                 1
# 101711     443207462                 1
# 101716     443237558                 1
# 101745     443797076                 1
# 101749     443816024                 1
# 101755     443842022                 1
# 101756     443842070                 1
# 101758     443842340                 1
# 101760     443847176                 1
#
# [11383 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['number_inpatient'], 25)
q3 = np.percentile(diabetes_df['number_inpatient'], 75)
iqr = q3-q1
outliers11 = q1-1.5*iqr
outliers12 = q3+1.5*iqr
df6 = diabetes_df[(diabetes_df['number_inpatient']<outliers11)|(diabetes_df['number_inpatient']>outliers12)]
df6[['encounter_id','number_inpatient']]
# Out:
#         encounter_id  number_inpatient
# 172          2549268                 3
# 175          2552952                 6
# 304          3156462                 3
# 410          3781500                 5
# 644          5056230                 5
# 675          5266116                 4
# 703          5357160                 3
# 733          5654628                 5
# 773          6000072                 3
# 777          6068238                 3
# 940          7212504                 6
# 953          7284348                 3
# 1042         7825020                 3
# 1045         7836894                 3
# 1063         7946712                 3
# 1066         7955598                 5
# 1173         8392890                 5
# 1203         8565288                 3
# 1281         9043872                 3
# 1304         9155802                 3
# 1349         9358128                 3
# 1354         9369882                 3
# 1388         9615816                 4
# 1421         9797892                 6
# 1425         9803076                 3
# 1426         9804066                 3
# 1550        10563816                 5
# 1584        10739064                 6
# 1597        10757838                 3
# 1663        11120142                 5
# ...              ...               ...
# 101341     437963144                 3
# 101369     438459530                 3
# 101371     438468824                 4
# 101385     438529178                 9
# 101391     438545384                 3
# 101397     438566858                 3
# 101404     438988466                 3
# 101426     439061744                 7
# 101447     439574054                 4
# 101459     439620116                 5
# 101468     439675868                 4
# 101476     439709192                 3
# 101482     439728398                 3
# 101508     440237120                 3
# 101550     440836964                 5
# 101555     440852402                 4
# 101579     441412274                 6
# 101596     441488810                 3
# 101599     441502826                 3
# 101601     441503084                 3
# 101611     441950420                 3
# 101620     441971606                 3
# 101629     442000934                12
# 101650     442515896                 8
# 101658     442552658                10
# 101685     443102726                 3
# 101699     443168882                 3
# 101701     443185706                 3
# 101709     443198486                 4
# 101734     443730002                 5
#
# [7049 rows x 2 columns]

# %%
q1 = np.percentile(diabetes_df['number_diagnoses'], 25)
q3 = np.percentile(diabetes_df['number_diagnoses'], 75)
iqr = q3-q1
outliers13 = q1-1.5*iqr
outliers14 = q3+1.5*iqr
df7 = diabetes_df[(diabetes_df['number_diagnoses']<outliers13)|(diabetes_df['number_diagnoses']>outliers14)]
df7[['encounter_id','number_diagnoses']]
# Out:
#         encounter_id  number_diagnoses
# 0            2278392                 1
# 66            715086                 1
# 216          2735964                 1
# 263          2948334                 1
# 431          3902532                 1
# 455          4065138                 1
# 933          7178106                 1
# 968          7331322                 1
# 996          7500936                 1
# 1004         7568742                 1
# 1076         7976388                 1
# 1177         8397792                 1
# 1350         9361848                 1
# 1574        10666374                 1
# 1675        11173470                 1
# 1791        11737752                 1
# 1850        12082878                 1
# 2163        14056032                 1
# 2392        15676788                 1
# 2468        16176624                 1
# 2654        17130798                 1
# 2782        17785530                 1
# 2794        17844570                 1
# 2828        18072510                 1
# 2841        18172458                 1
# 2860        18298074                 1
# 2893        18476064                 1
# 3054        19420404                 1
# 3153        19897218                 1
# 3766        22583910                 1
# ...              ...               ...
# 97345      387368372                16
# 97422      388487156                14
# 97428      388506194                16
# 97482      389106974                16
# 97761      392590034                16
# 97787      392660828                16
# 98394      400265684                16
# 98436      400859708                16
# 98994      407922710                16
# 99390      412649528                16
# 99393      412690112                16
# 99628      415548776                16
# 99830      417979916                16
# 99916      419114912                14
# 100258     423267692                16
# 100374     424949456                15
# 100514     426737732                16
# 100677     429120578                16
# 100787     430828958                 1
# 101027     433819448                15
# 101031     433830680                16
# 101147     435554492                14
# 101297     437391758                16
# 101335     437939822                15
# 101557     440860496                16
# 101603     441510854                14
# 101646     442098572                16
# 101682     442680734                15
# 101719     443256548                 1
# 101751     443835140                16
#
# [281 rows x 2 columns]

# %% [markdown]
# ## Using the `seaborn.catplot` function, create a plot according to the following specifications:
#
#  * Each of the columns listed above should be a subplot
#  * For each, you should plot a boxplot
#  * Each row of subplots should have 2 plots (except for the last one, since there are an odd number of plots)
#  * Each row should not share a y-axis
#
# You can find the documentation for the catplot function [here](https://seaborn.pydata.org/generated/seaborn.catplot.html#seaborn.catplot)

# %% [markdown]
# #### Create a subset of the diabetes dataframe that just contains those columns [2.5]

# %%
sub_df = diabetes_df[['num_lab_procedures','num_procedures','num_medications','number_outpatient','number_emergency','number_inpatient','number_diagnoses']]
sub_df
# Out:
#         num_lab_procedures  num_procedures  num_medications  \
# 0                       41               0                1
# 1                       59               0               18
# 2                       11               5               13
# 3                       44               1               16
# 4                       51               0                8
# 5                       31               6               16
# 6                       70               1               21
# 7                       73               0               12
# 8                       68               2               28
# 9                       33               3               18
# 10                      47               2               17
# 11                      62               0               11
# 12                      60               0               15
# 13                      55               1               31
# 14                      49               5                2
# 15                      75               5               13
# 16                      45               4               17
# 17                      29               0               11
# 18                      35               5               23
# 19                      42               2               23
# 20                      66               1               19
# 21                      36               2               11
# 22                      47               0               12
# 23                      42               2               19
# 24                      19               4               18
# 25                      33               0                7
# 26                      64               3               18
# 27                      25               2               11
# 28                      53               0               20
# 29                      52               0               14
# ...                    ...             ...              ...
# 101736                  54               1               20
# 101737                  50               4               25
# 101738                  37               0               10
# 101739                  32               6               14
# 101740                   1               5                8
# 101741                  21               1                8
# 101742                  43               0               10
# 101743                  45               0               26
# 101744                  49               0               12
# 101745                  57               0                7
# 101746                   2               0                7
# 101747                  51               6               19
# 101748                  69               0               16
# 101749                  27               1               29
# 101750                  31               2               24
# 101751                  77               6               65
# 101752                  13               1                5
# 101753                  51               2               13
# 101754                  50               2               33
# 101755                  73               6               26
# 101756                  46               6               17
# 101757                  21               1               16
# 101758                  76               1               22
# 101759                   1               0               15
# 101760                  45               1               25
# 101761                  51               0               16
# 101762                  33               3               18
# 101763                  53               0                9
# 101764                  45               2               21
# 101765                  13               3                3
#
#         number_outpatient  number_emergency  number_inpatient  \
# 0                       0                 0                 0
# 1                       0                 0                 0
# 2                       2                 0                 1
# 3                       0                 0                 0
# 4                       0                 0                 0
# 5                       0                 0                 0
# 6                       0                 0                 0
# 7                       0                 0                 0
# 8                       0                 0                 0
# 9                       0                 0                 0
# 10                      0                 0                 0
# 11                      0                 0                 0
# 12                      0                 1                 0
# 13                      0                 0                 0
# 14                      0                 0                 0
# 15                      0                 0                 0
# 16                      0                 0                 0
# 17                      0                 0                 0
# 18                      0                 0                 0
# 19                      0                 0                 0
# 20                      0                 0                 0
# 21                      0                 0                 0
# 22                      0                 0                 0
# 23                      0                 0                 0
# 24                      0                 0                 0
# 25                      0                 0                 0
# 26                      0                 0                 0
# 27                      0                 0                 0
# 28                      0                 0                 0
# 29                      0                 0                 0
# ...                   ...               ...               ...
# 101736                  1                 0                 1
# 101737                  0                 0                 0
# 101738                  0                 0                 2
# 101739                  2                 0                 2
# 101740                  0                 0                 0
# 101741                  0                 0                 1
# 101742                  0                 0                 0
# 101743                  1                 0                 1
# 101744                  0                 0                 0
# 101745                  0                 1                 0
# 101746                  1                 0                 0
# 101747                  0                 0                 0
# 101748                  0                 0                 0
# 101749                  0                 1                 0
# 101750                  0                 0                 0
# 101751                  0                 0                 0
# 101752                  0                 0                 0
# 101753                  0                 0                 0
# 101754                  0                 0                 0
# 101755                  0                 1                 0
# 101756                  1                 1                 1
# 101757                  0                 0                 1
# 101758                  0                 1                 0
# 101759                  3                 0                 0
# 101760                  3                 1                 2
# 101761                  0                 0                 0
# 101762                  0                 0                 1
# 101763                  1                 0                 0
# 101764                  0                 0                 1
# 101765                  0                 0                 0
#
#         number_diagnoses
# 0                      1
# 1                      9
# 2                      6
# 3                      7
# 4                      5
# 5                      9
# 6                      7
# 7                      8
# 8                      8
# 9                      8
# 10                     9
# 11                     7
# 12                     8
# 13                     8
# 14                     8
# 15                     9
# 16                     8
# 17                     3
# 18                     9
# 19                     8
# 20                     7
# 21                     6
# 22                     8
# 23                     8
# 24                     6
# 25                     3
# 26                     7
# 27                     3
# 28                     6
# 29                     8
# ...                  ...
# 101736                 9
# 101737                 9
# 101738                 7
# 101739                 9
# 101740                 4
# 101741                 9
# 101742                 9
# 101743                 9
# 101744                 9
# 101745                 3
# 101746                 5
# 101747                 9
# 101748                 5
# 101749                 9
# 101750                 9
# 101751                16
# 101752                 8
# 101753                 9
# 101754                 9
# 101755                 9
# 101756                 9
# 101757                 9
# 101758                 9
# 101759                 7
# 101760                 9
# 101761                 9
# 101762                 9
# 101763                13
# 101764                 9
# 101765                 9
#
# [101766 rows x 7 columns]

# %% [markdown]
# #### Currently, the dataframe is in wide-form. Instead, change the dataframe so that the category name is in one column, and all the values are stacked in another (melted) [7.5]

# %%
melted = sub_df.melt()
melted
# Out:
#                   variable  value
# 0       num_lab_procedures     41
# 1       num_lab_procedures     59
# 2       num_lab_procedures     11
# 3       num_lab_procedures     44
# 4       num_lab_procedures     51
# 5       num_lab_procedures     31
# 6       num_lab_procedures     70
# 7       num_lab_procedures     73
# 8       num_lab_procedures     68
# 9       num_lab_procedures     33
# 10      num_lab_procedures     47
# 11      num_lab_procedures     62
# 12      num_lab_procedures     60
# 13      num_lab_procedures     55
# 14      num_lab_procedures     49
# 15      num_lab_procedures     75
# 16      num_lab_procedures     45
# 17      num_lab_procedures     29
# 18      num_lab_procedures     35
# 19      num_lab_procedures     42
# 20      num_lab_procedures     66
# 21      num_lab_procedures     36
# 22      num_lab_procedures     47
# 23      num_lab_procedures     42
# 24      num_lab_procedures     19
# 25      num_lab_procedures     33
# 26      num_lab_procedures     64
# 27      num_lab_procedures     25
# 28      num_lab_procedures     53
# 29      num_lab_procedures     52
# ...                    ...    ...
# 712332    number_diagnoses      9
# 712333    number_diagnoses      9
# 712334    number_diagnoses      7
# 712335    number_diagnoses      9
# 712336    number_diagnoses      4
# 712337    number_diagnoses      9
# 712338    number_diagnoses      9
# 712339    number_diagnoses      9
# 712340    number_diagnoses      9
# 712341    number_diagnoses      3
# 712342    number_diagnoses      5
# 712343    number_diagnoses      9
# 712344    number_diagnoses      5
# 712345    number_diagnoses      9
# 712346    number_diagnoses      9
# 712347    number_diagnoses     16
# 712348    number_diagnoses      8
# 712349    number_diagnoses      9
# 712350    number_diagnoses      9
# 712351    number_diagnoses      9
# 712352    number_diagnoses      9
# 712353    number_diagnoses      9
# 712354    number_diagnoses      9
# 712355    number_diagnoses      7
# 712356    number_diagnoses      9
# 712357    number_diagnoses      9
# 712358    number_diagnoses      9
# 712359    number_diagnoses     13
# 712360    number_diagnoses      9
# 712361    number_diagnoses      9
#
# [712362 rows x 2 columns]

# %% [markdown]
# #### Use the catplot function to plot the graph. Make sure to adhere to each of the conditions listed above [10]

# %%
sns.catplot(col='variable', y='value', data=melted, kind='box', sharey=False, col_wrap=2, height=3, aspect=1.5)

# %% [markdown]
# ## Making cosmetic changes and Checking the boxplot outlier implementation:
#
# The *whiskers* of a boxplot often extend to the bounds for outliers. However, some boxplot implementations choose other bounds for the whiskers, such as the maximum and minimum values, or a set percentile (10th, 90th, etc). In this next step, you will utilize `matplotlib`'s `Axes` objects to change the subplots in some way.

# %% [markdown]
# Recall that Seaborn (and many other plotting libraries) are built off of `matplotlib` objects. Therefore, you can always modify these plots with all of the custom functions that are available in `matplotlib`'s interface. To access the `Axes` objects of your plot, save your plot to a variable, and call
#
# `variable.axes`

# %% [markdown]
# You should see an array of `Axes` objects appear. These will be objects that you set attributes of in order to modify your plots.

# %% [markdown]
# Note: You may have to copy your plot code from above into another cell because of the way jupyter handles plots.

# %% [markdown]
# ### Clean up the titles for each graph so that they are either the name of the columns or a cleaner representation [10 pts]

# %% [markdown]
# For example, rather than `variable = number_emergency`, you can set it to `number_emergency`, or `Number of Emergency Visits`.

# %% [markdown]
# you can do this by accessing the `Axes`, and using `set(title =)`.

# %%
# fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2, sharey=False, figsize=(10,10))

# plot1 = sub_df['num_lab_procedures'].plot(kind = 'box')
# plot1.axes.set(title = 'num_lab_procedures')

# %%
g = sns.catplot(col='variable', y='value', data=melted, kind='box', sharey=False, col_wrap=2, height=3, aspect=1.5)
g = g.set_titles("{col_name} {col_var}")

# %% [markdown]
# ### Add dotted lines at each of the upper and lower outlier bounds. Pick a non-default color and linestyle of your choice for these [10 pts]

# %% [markdown]
# To check if seaborn boxplots use the same outlier method for determining the bound of the whiskers, add a dotted line at the upper and lower bound of each of these columns with a non-default color and linestyle and see if they line up with the seaborn boxplot whiskers

# %%
g = sns.catplot(col='variable', y='value', data=melted, kind='box', sharey=False, col_wrap=2, height=3, aspect=1.5)
g = g.set_titles("{col_name} {col_var}")

ax = g.axes

ax[0].axhline(y=outliers1,linestyle='-.',color='r')
ax[0].axhline(y=outliers2,linestyle='-.',color='g')

ax[1].axhline(y=outliers3,linestyle='-.',color='r')
ax[1].axhline(y=outliers4,linestyle='-.',color='g')

ax[2].axhline(y=outliers5,linestyle='-.',color='r')
ax[2].axhline(y=outliers6,linestyle='-.',color='g')

ax[3].axhline(y=outliers7,linestyle='-.',color='r')
ax[3].axhline(y=outliers8,linestyle='-.',color='g')

ax[4].axhline(y=outliers9,linestyle='-.',color='r')
ax[4].axhline(y=outliers10,linestyle='-.',color='g')

ax[5].axhline(y=outliers11,linestyle='-.',color='r')
ax[5].axhline(y=outliers12,linestyle='-.',color='g')

ax[6].axhline(y=outliers13,linestyle='-.',color='r')
ax[6].axhline(y=outliers14,linestyle='-.',color='g')

g

# %%
# g.axes[0].axhline(y= outliers1)
# g.axes[0].axhline(y= outliers2)
# plt.axhline(y=outliers1,linestyle='-.',color='r')
# plt.axhline(y=outliers2,linestyle='-.',color='g')

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# In the [paper that produced the dataset](https://www.hindawi.com/journals/bmri/2014/781670/), the authors perform a series of hypothesis tests. However, as is common in the literature, they often do not provide confidence intervals or explain which hypothesis tests were performed. Here, we want to reproduce the results of the paper, but to generate confidence intervals so we have a better sense of the uncertainty behind their results.

# %% [markdown]
# ### Test:
#
# > When an HbA1c was not obtained, 42.5% of patients had a medication change during the hospitalization, whereas those providers who ordered the test appear to have been somewhat more responsive as determined by changes in medication (55.0%, P < 0.001).

# %% [markdown]
# Here, we can represent this statement as the following hyptothesis test:
#
# $$ H_0: p_1 = p_2 $$
# $$ H_1: p_1 \neq p_2 $$
#
# Equivalently:
#
# $$ H_0: p_1 - p_2 = 0$$
# $$ H_1: p_1 - p_2 \neq 0$$

# %% [markdown]
# where p is the probability that a provider changed the medication (given by the `change` column)

# %% [markdown]
# In order to test the equality of two proportions, the Z-test for 2 proportions is often used. In this setting, the test statistic is distributed according to the standard normal distribution: N(0, 1)

# %% [markdown]
# $$ Z_t = \frac{\hat{p_1} - \hat{p_2}}{\hat{\sigma_D}} $$

# %% [markdown]
# Here, $\hat{p_1}$ and $\hat{p_2}$ are the observed proportions of a provider changing a medication.

# %% [markdown]
# Here, we will assume that the two populations have the same variance, meaning we can use what is known as a *pooled standard error*. The details of this are outside the scope of this course.

# %% [markdown]
# $$\hat{p} = \frac{n_1\hat{p_1} + n_2\hat{p_2}}{n_1 + n_2} $$
#
# $$\hat{\sigma_D} = \sqrt{\hat{p}(1-\hat{p})(\frac{1}{n_1} + \frac{1}{n_2})}$$
#
# where $n_1$ and $n_2$ are the sample sizes for groups 1 and 2, respectively

# %% [markdown]
# In this case, the assumptions for the test are as follows:
#
#  * The two populations are independent
#  * They are sampled at random
#  * There is enough data such that
#      * $np > 10$
#      * $n(1-p) > 10$
#
# which we can assume holds in this case.

# %% [markdown]
# Compute $\hat{p_1}$ and $\hat{p_2}$ by checking the proportion of the time that the `change` column is equal to `Ch` when the A1C column is *not* None ($\hat{p_1}$) versus when it is None ($\hat{p_2}$). You can use `pd.isnull()` to check where a column is missing. Note that the numbers may be slightly off of the numbers from the paper due to the way that they remove certain encounters

# %%
pd.isnull(diabetes_df[['A1Cresult','change']]).sum()
# Out:
# A1Cresult    0
# change       0
# dtype: int64

# %%
df1 = diabetes_df[(diabetes_df['A1Cresult'] != "None")]
n1 = len(df1)

df1_change = df1[(df1['change'] == "Ch")]
n1_change = len(df1_change)

n1,n1_change
# Out:
# (17018, 9490)

# %%
df2 = diabetes_df[(diabetes_df['A1Cresult'] == "None")]
n2 = len(df2)

df2_change = df2[(df2['change'] == "Ch")]
n2_change = len(df2_change)

n2,n2_change
# Out:
# (84748, 37521)

# %%
p1 = n1_change/n1
p2 = n2_change/n2
p1,p2
# Out:
# (0.5576448466329769, 0.44273611176664934)

# %% [markdown]
# #### Next, compute the value of the test statistic: [15 pts]

# %%
from math import sqrt
p = (n1*p1+n2*p2)/(n1+n2)
sigma = sqrt(p*(1-p)*(1/n1+1/n2))
z = (p1-p2)/sigma
z
# Out:
# 27.438587305291865

# %% [markdown]
# Because the Z-statistic is distributed according to the standard Normal Distribution, we can find the p-value by using the `norm.cdf()` command. Remember, the p-value is just the probability that we would see a test-statistic as extreme or more extreme given that the null hypothesis was true.
#
# Because our alternative hypothesis is 2-sided, we can compute the p-value as follows:
#
# `norm.cdf(z) * 2`
#
# This is because we allow for our test statistic to be either greater than OR less than the critical values.

# %% [markdown]
# #### Compute the p-value [10 pts]

# %%
from scipy.stats import norm

p_value = norm.cdf(-z)*2 
p_value
# Out:
# 9.506951357707911e-166

# %% [markdown]
# #### Verify using the following method that your test statistic and p-value match [5 pts]

# %%
import statsmodels.api as sm
z_score, p_value = sm.stats.proportions_ztest([n1_change, n2_change], [n1, n2]) 
# fill in the code here:
# Resource: http://knowledgetack.com/python/statsmodels/proportions_ztest/

z_score, p_value
# Out:
# (27.438587305291865, 9.506951357707911e-166)

# %% [markdown]
# #### An aside:
#
# To find the value of the test statistic that would give us exactly 0.05 significance, we can use:
#
# `normQuantile(0.025)`
# and
# `normQuantile(0.975)`
#
# (where the `normQuantile` function (which in scipy is `norm.ppf`) tells us what at what value the Cumulative Distribution Function is equal to the argument. The quantile function is the inverse of the Cumulative Distribution Function)
#
#
# As this gives us half of the 0.05 significance level on either side.
#
# For one sided tests, this would just be
#
# `normQuantile(0.05)`
# or
# `normQuantile(0.95)`
# depending on the direction of the alternative hypothesis

# %% [markdown]
# ### Confidence Interval

# %% [markdown]
# Next, we're going to construct a confidence interval. The p-value just tells us that it is unlikely, given that the null hypothesis is true, that we would see data as extreme or more extreme than what we saw. In other words, if there were no difference in the way that physicians changed diabetes patients' medications depending on whether they tested for A1C or not, then it would be highly unlikely that we would see a pattern as extreme as we see in the data.

# %% [markdown]
# However, this does not tell us *anything* about how different the values actually are. To generate a 95% confidence interval, we take the *observed* difference in proportions and construct it in the following way:

# %% [markdown]
# $\hat{p_1} - \hat{p_2} \pm Z_* \sigma_D$
#
# Where $Z_*$ here is `normQuantile(0.975)` or `normQuantile(0.025)` (the only difference is the sign change)

# %% [markdown]
# ### Find the confidence interval for this test [10 pts]

# %% [markdown]
# This tells us that in a specific example of this procedure being run, there is a 95% probability that the true difference between the means falls between the two bounds. Remember that this says nothing about whether the true difference is in these bounds or not!

# %%
z_star = norm.ppf(0.975)
low_interval = p1-p2 - z_star*sigma
up_interval = p1-p2 + z_star*sigma
(low_interval,up_interval)
# Out:
# (0.10670069633499876, 0.12311677339765628)
